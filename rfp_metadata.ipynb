# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
from upload_rfp_sim import extract_rfi_metadata_from_file

# %%
file_path = r"C:\Users\jhagan.a\Documents\Tetratech\RPFRFIs\five_splitted\705-22295407.00-B&M_HONI RFP-Chatham SS-Chatham_Lakeshore App AI Elect Install Works 1\705-22295407.00-B&M_HONI RFP-Chatham SS-Chatham_Lakeshore App AI Elect Install Works.pdf"

# %%
metadata = asyncio.get_event_loop().run_until_complete(extract_rfi_metadata_from_file(file_path))
print(metadata)
# Out:
# C:\Python312\Lib\ast.py:52: RuntimeWarning: coroutine 'extract_rfi_metadata_from_file' was never awaited
#   return compile(source, filename, mode, flags,
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 metadata = asyncio.get_event_loop().run_until_complete(extract_rfi_metadata_from_file(file_path))
#       2 print(metadata)
#
# File c:\Users\jhagan.a\Documents\Tetratech\Data ingestion\document_processing_modular_code_Jhagan\document_processing_modular_code-Jhagan-app-logging\venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Python312\Lib\asyncio\futures.py:202, in Future.result(self)
#     200 self.__log_traceback = False
#     201 if self._exception is not None:
# --> 202     raise self._exception.with_traceback(self._exception_tb)
#     203 return self._result
#
# File C:\Python312\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File c:\Users\jhagan.a\Documents\Tetratech\Data ingestion\document_processing_modular_code_Jhagan\document_processing_modular_code-Jhagan-app-logging\upload_rfp_sim.py:12, in extract_rfi_metadata_from_file(file_path)
#      10 text_extractor = TextExtractor()
#      11 # You need to implement this function to parse your file into text_elements and DI result
# ---> 12 result = text_extractor.load_document_intelligence_result(file_path)
#      13 text_elements = text_extractor.extract_text(result)
#      15 rfi_extractor = RFIExtractor()
#
# AttributeError: 'TextExtractor' object has no attribute 'load_document_intelligence_result'
# <frozen genericpath>:89: RuntimeWarning: coroutine 'extract_rfi_metadata_from_file' was never awaited
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
